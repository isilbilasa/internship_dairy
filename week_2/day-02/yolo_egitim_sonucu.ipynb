# %%
# %pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data='market_dataset-2/data.yml',
    epochs=50,
    imgsz=640,
    plots=True
)
